# %%
import gzip

path = '/dss/dsslegfs01/pr53da/pr53da-dss-0018/projects/2020__ancientDNA/05_aDNA/01_angsd_enrichedallfresh_rescaled'
trans = open('enrichedallfresh_rescaled_outlier_hapconsensus_maxmis_q20.haplo.transversion', "w")
with gzip.open('enrichedallfresh_rescaled_outlier_hapconsensus_maxmis_q20.haplo.gz', 'rt') as f:
    for line in f:
        df=line.split()
        base=df[3:]
        unique = sorted(set(base))
        check = "".join(str(x) for x in unique)
        if check == 'AG' or check == 'AGN' or check == 'CT' or check == 'CNT':
            ""
        else:
            trans.write(line)
trans.close()

# %%
import gzip

path = '/dss/dsslegfs01/pr53da/pr53da-dss-0018/projects/2020__ancientDNA/05_aDNA/01_angsd_enrichedallfresh_rescaled'
trans = open('enrichedallfresh_rescaled_outlier_haprandom_maxmis_q20.haplo.transversion', "w")
with gzip.open('enrichedallfresh_rescaled_outlier_haprandom_maxmis_q20.haplo.gz', 'rt') as f:
    for line in f:
        df=line.split()
        base=df[3:]
        unique = sorted(set(base))
        check = "".join(str(x) for x in unique)
        if check == 'AG' or check == 'AGN' or check == 'CT' or check == 'CNT':
            ""
        else:
            trans.write(line)
trans.close()

# %%
import gzip

path = '/dss/dsslegfs01/pr53da/pr53da-dss-0018/projects/2020__ancientDNA/05_aDNA/01_angsd_enrichedallfresh_rescaled'
trans = open('enrichedallfresh_rescaled_neutral_hapconsensus_maxmis_q20.haplo.transversion', "w")
with gzip.open('enrichedallfresh_rescaled_neutral_hapconsensus_maxmis_q20.haplo.gz', 'rt') as f:
    for line in f:
        df=line.split()
        base=df[3:]
        unique = sorted(set(base))
        check = "".join(str(x) for x in unique)
        if check == 'AG' or check == 'AGN' or check == 'CT' or check == 'CNT':
            ""
        else:
            trans.write(line)
trans.close()

# %%
import gzip

path = '/dss/dsslegfs01/pr53da/pr53da-dss-0018/projects/2020__ancientDNA/05_aDNA/01_angsd_enrichedallfresh_rescaled'
trans = open('enrichedallfresh_rescaled_neutral_haprandom_maxmis_q20.haplo.transversion', "w")
with gzip.open('enrichedallfresh_rescaled_neutral_haprandom_maxmis_q20.haplo.gz', 'rt') as f:
    for line in f:
        df=line.split()
        base=df[3:]
        unique = sorted(set(base))
        check = "".join(str(x) for x in unique)
        if check == 'AG' or check == 'AGN' or check == 'CT' or check == 'CNT':
            ""
        else:
            trans.write(line)
trans.close()
